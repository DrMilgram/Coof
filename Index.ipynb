# %% [markdown]
# # Welcome to Jupyter!

# %% [markdown]
# Use ctrl+enter to run the code

# %%
import matplotlib.pyplot as plt
import urllib
import json

link = "https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-json/dpc-covid19-ita-andamento-nazionale.json"
f = urllib.request.urlopen(link)
data = json.load(f)

plt.plot([d["nuovi_positivi"] for d in data])
#plt.plot([d["totale_positivi"] for d in data])
plt.ylabel('some numbers')
plt.show()
